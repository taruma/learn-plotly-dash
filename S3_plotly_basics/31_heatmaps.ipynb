# %%
import plotly.io as pio
from umaplotly import uma_template

pio.templates.default = uma_template

# %%
import plotly.graph_objects as go
import pandas as pd

# %%
df = pd.read_csv(
    r'..\source\Plotly-Dashboards-with-Dash\Data\2010SantaBarbaraCA.csv')
# df = pd.read_csv(r'..\source\Plotly-Dashboards-with-Dash\Data\2010YumaAz.csv')
df
# Out:
#      LST_DATE      DAY LST_TIME  T_HR_AVG
# 0    20100601  TUESDAY     0:00      12.7
# 1    20100601  TUESDAY     1:00      12.7
# 2    20100601  TUESDAY     2:00      12.3
# 3    20100601  TUESDAY     3:00      12.5
# 4    20100601  TUESDAY     4:00      12.7
# ..        ...      ...      ...       ...
# 163  20100607   MONDAY    19:00      15.6
# 164  20100607   MONDAY    20:00      14.8
# 165  20100607   MONDAY    21:00      14.3
# 166  20100607   MONDAY    22:00      14.4
# 167  20100607   MONDAY    23:00      14.6
#
# [168 rows x 4 columns]

# %%
data = [
    go.Heatmap(
        x=df.DAY,
        y=df.LST_TIME,
        z=df.T_HR_AVG,
        colorscale='jet'
    )
]

layout = go.Layout(title='SB CA Temps')

go.Figure(data, layout)

# %% [markdown]
# # MULTIPLE HEAT MAPS WITH SUBPLOTS

# %%
from plotly.subplots import make_subplots

df1 = pd.read_csv(
    r'..\source\Plotly-Dashboards-with-Dash\Data\2010SitkaAK.csv')
df2 = pd.read_csv(
    r'..\source\Plotly-Dashboards-with-Dash\Data\2010SantaBarbaraCA.csv')
df3 = pd.read_csv(r'..\source\Plotly-Dashboards-with-Dash\Data\2010YumaAZ.csv')

titles = ['Sitka AK', 'SB CA', 'Yuma AZ']

traces = [
    go.Heatmap(
        x=df.DAY, y=df.LST_TIME, z=df.T_HR_AVG, colorscale='jet', zmin=5, zmax=40, name=title
    )
    for df, title in zip([df1, df2, df3], titles)
]


fig = make_subplots(
    rows=1, cols=3, subplot_titles=titles, shared_yaxes=True
)

for i, trace in enumerate(traces, 1):
    fig.add_trace(trace, 1, i)

fig.update_layout(title='Temp for 3 Cities')

# %%
#######
# Objective: Make a DataFrame using the Abalone dataset (../data/abalone.csv).
# Take two independent random samples of different sizes from the 'rings' field.
# HINT: np.random.choice(df['rings'],10,replace=False) takes 10 random values
# Use box plots to show that the samples do derive from the same population.
######

# Perform imports here:

import pandas as pd
import plotly.graph_objects as go
import plotly.io as pio
from umaplotly import uma_template

pio.templates.default = uma_template

# %%
# create a DataFrame from the .csv file:
df = pd.read_csv(r'..\source\Plotly-Dashboards-with-Dash\Data\abalone.csv')
df
# Out:
#      sex  length  diameter  height  whole_weight  shucked_weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       viscera_weight  shell_weight  rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
# take two random samples of different sizes:
import numpy as np

samples = [np.random.choice(df.rings, 100, replace=False) for _ in range(5)]
# samples

# %%
# create a data variable with two Box plots:

data = [
    go.Box(
        y=sample,
    )
    for sample in samples
]

layout = go.Layout(hovermode='x')

# create a fig from data & layout, and plot the fig
go.Figure(data, layout)
